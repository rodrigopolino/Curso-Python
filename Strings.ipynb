# %% [markdown]
# Índice e tamanho de String

# %%
texto = "Rodrigo"
print(texto[1]) #item do texto
len(texto) #tamanho do texto
# Out:
# o
# 7

# %% [markdown]
# Índice negativo e pedaço de String

# %%
texto = "abacate"
print(texto[-1]) #última letra / carctere

email = "rodrigo.polino@outlook.com"
print(email[:14]) #texto todo menos os últimos dois cartacteres
print(email[14:])
print(email[8:14])
# Out:
# e
# rodrigo.polino
# @outlook.com
# polino

# %% [markdown]
# Operações com String

# %%
faturamento = 1000
custo = 500
lucro = faturamento - custo

# %%
print("O faturamento da loja foi de: " + str(faturamento))
# Out:
# O faturamento da loja foi de: 1000

# %%
print("O faturamente foi de: {}".format(faturamento))
print("O faturamento foi de: {}. O custo foi de {} e o lucro foi de {}".format(faturamento, custo, lucro))
print("O faturamento foi de: {0}. O custo foi de {1}. Lembrando, o faturamento foi de {0}".format(faturamento, custo))
# Out:
# O faturamente foi de: 1000
# O faturamento foi de: 1000. O custo foi de 500 e o lucro foi de 500
# O faturamento foi de: 1000. O custo foi de 500. Lembrando, o faturamento foi de 1000

# %%
print("O faturamento foi de: %d." % faturamento) #d - substituir por um número
print("O faturamento foi de: %s") #s - substituir por uma string
# Out:
# O faturamento foi de: 1000.
# O faturamento foi de: %s

# %%
print('@' in 'rodrigo.polino@gmail.com')
print('#' in 'rodrigo.polino@gmail.com')
# Out:
# True
# False

# %% [markdown]
# Métodos de String - (Fórmula)

# %%
nome = "rodrigo"
print(nome.capitalize()) # Primeira letra maiúscula

nome = "Rodrigo"
print(nome.casefold()) # Primeira letra minúscula

email = "rodrigo@gmail.com"
print(email.count('o')) # Conta a quantidade de argumento

print(email.endswith('gmail.com')) # Verifica se o texto termina com o conjunto de caracter

print(email.find('@')) # Retorna a posição do argumento

text = 'Rodrigo123'
print(text.isalnum()) # Verifica se o texto é feito de caracteres alfanuméricos

text = "Rodrigo"
print(text.isalpha()) # Verifica se o texto é feito de letras

text = "123"
print(text.isnumeric()) # Verifica se o texto é numérico

preco = "1000.00"
print(preco.replace('.', ',')) # Troca o valor de algum caractere

email = "rodrigo@gmail.com"
print(email.split("@")) # Separa o texto pelo caractere selecionado

texto = '''Olá, bom dia
Venho por este e-mail lhe informar o faturamento da loja no dia de hoje.
Faturamento = R$2.500,00'''
print(texto.splitlines()) # Separa um texto em vários textos de acordo com os "enters" do texto

senha = "BEB12345"
print(senha.startswith('BEB12')) # Verica se o texto começa de acordo com o argumento

senha = "   BEGF14235 4 "
print(senha.strip()) # Retira trechos indesejados do texto

nome = "rodrigo polino filippini"
print(nome.title()) # Coloca a 1ª letra em maiúsculo

nome = "RODRIGO"
print(nome.lower()) # Coloca texto em maiúsculo

nome = "rodrigo"
print(nome.upper()) # Coloca texto em minúsculo
# Out:
# Rodrigo
# rodrigo
# 3
# True
# 7
# True
# True
# True
# 1000,00
# ['rodrigo', 'gmail.com']
# ['Olá, bom dia', 'Venho por este e-mail lhe informar o faturamento da loja no dia de hoje.', 'Faturamento = R$2.500,00']
# True
# BEGF14235 4
# Rodrigo Polino Filippini
# rodrigo
# RODRIGO

# %% [markdown]
# Formatação de números

# %%
#Exemplo de alinhamento  ({:<}, {:>}, {:^})
email = "rodrigopolino@outlook.com"
print("Meu email não é {:<30}, ok?".format(email))

#Exemplo de sinal   ({:+}, {:-})
custo = 5000
faturamento = 2700
lucro = faturamento - custo
print("Faturamento foi {:+} e lucro foi {:-}".format(faturamento, lucro))

#Exemplo de separador de milhar
print("Faturamento foi {:+,} e lucro foi {:-,}".format(faturamento, lucro))

#Formato com casas decimais fixas
print("Faturamento foi {:,.2f} e lucro foi {:.2f}".format(faturamento, lucro))

#Formato Percentual
custo = 200
faturamento = 1300
lucro = faturamento - custo
margem = lucro / faturamento
print("Faturamento foi R${:.2%}".format(margem))

#Formato Moeda
print("Margem de lucro foi de {:,.2f} e lucro foi R${:,.2f}".format(faturamento, lucro))
#formato brasileiro
lucro_texto = "R${:_.2f}".format(lucro)
print(lucro_texto)
print(lucro_texto.replace('.', ',').replace('_', '.'))

#Função round - Arredondar números
imposto = 0.12758
preco = 100
valor_imposto = round(preco * imposto, 2)
print("Imposto sobre o preço é de {}".format(valor_imposto))
# Out:
# Meu email não é rodrigopolino@outlook.com     , ok?
# Faturamento foi +2700 e lucro foi -2300
# Faturamento foi +2,700 e lucro foi -2,300
# Faturamento foi 2,700.00 e lucro foi -2300.00
# Faturamento foi R$84.62%
# Margem de lucro foi de 1,300.00 e lucro foi R$1,100.00
# R$1_100.00
# R$1.100,00
# Imposto sobre o preço é de 12.76

# %% [markdown]
# Exercícios

# %% [markdown]
# **1. Cadastro de CPF**
#
# Crie um programa para cadastro de CPF de clientes que recebe o CPF em um input box apenas com números.
#
# Ex: 'Insira seu CPF (digite apenas números)'
#
# Caso o usuário digite algo diferente de números ou digite menos de 11 caracteres (tamanho do CPF brasileiro), o programa deve exibir uma mensagem de "Digite seu CPF corretamente e digite apenas números"

# %%
cpf = input("Insira seu CPF (digite apenas números): ")

if len(cpf) == 11 and cpf.isnumeric():
  print(cpf)
else:
  print("Digite seu CPF corretamente e digite apenas números")
# Out:
# Insira seu CPF (digite apenas números): 1efe2456789
# Digite seu CPF corretamente e digite apenas números

# %% [markdown]
# **2. Melhorando nosso Cadastro de CPF**
#
# Agora, além das validações anteriores, vamos criar um input que permita que o usuário insira pontos, traços e inclusive espaços vazios.
#
# Nosso programa deve "tratar" o que o usuário inserir para padronizar o CPF dele em apenas números.
#
# A verificação de tamanho do CPF com 11 caracteres continua válida, mas ela só deve ser feita depois de retirar todos os pontos, traços e espaços do CPF que o cliente inserir e, uma vez retirados pontos, traços e espaços, devem sobrar apenas números no CPF. Qualquer outro caractere deve ser considerado inválido.
#
# No final, nosso programa deve exibir uma mensagem para o usuário, caso ele tenha inserido o CPF inválido ou então apenas deve printar o CPF correto já só com número.

# %%
#tirar espaço início e final, traços e pontos
cpf = input("Insira seu CPF (digite apenas números): ").strip().replace('.', '').replace('-', '')
if len(cpf) == 11 and cpf.isnumeric():
  print(cpf)
else:
  print("Digite seu CPF corretamente e digite apenas números")
# Out:
# Insira seu CPF (digite apenas números):     12345678911
# 12345678911

# %% [markdown]
# **3. Cadastro de e-mails**
#
# - A Hashtag sempre se comunica com seus clientes por e-mail. Para isso, a gente tem em cada página um cadastro de nome e e-mail. Nesse cadastro, nosso sistema verifica se o e-mail que a pessoa inseriu é um e-mail válido, verificando se ele tem '@' e se depois do '@' tem algum ponto, afinal:
#
# - liragmail.com NÃO é um e-mail válido
# - lira@gmail NÃO é um e-mail válido
# - lira@gmail.com é um e-mail válido
#
# Crie um programa que permita o cadastro de nome e e-mail de uma pessoa (por meio de inputs) e que verifique:
# 1. Se nome e e-mail foram preenchidos, caso contrário ele deve avisar para preencher todos os dados corretamente
# 2. Se o e-mail contém '@' e se depois do '@' existe algum '.', caso contrário ele deve exibir uma mensagem de e-mail inválido
#
# Obs: Pode te ajudar lembrar do método .find da aula de Métodos de String. Você pode testar o que ele dá como resposta caso ele não encontre um item dentro da string

# %%
nome = input("Digite seu nome: ")
email = input("Digite seu e-mail: ")

if nome and email:
  pos_a = email.find('@') #retorna posição
  servidor = email[pos_a:]
  if pos_a != -1 and '.' in servidor:
    print("Cadastro concluído!")
  else:
    print("E-mail inválido")
else:
  print("Digite seu nome e e-mail corretamente")
# Out:
# Digite seu nome: rodrigo
# Digite seu e-mail: rodrigo@gmailcom
# E-mail inválido

# %% [markdown]
# Cortes de String

# %%
#Forma Básica
precos = "Jan: 25, Fev: 27, Mar: 29"

preco_jan = precos[5:7] # pos 5=2, pos 6=5
print(preco_jan)

#Posição Inicial e Final
preco_mar = precos[-2:]
print(preco_mar)

preco_fev = precos[14:16] # precos[-11:-9]
print(preco_fev)

#Posição Inicial e Final com Step
codigo = "1.2.3.4,5,1,2.3.4,7.9"
pedaco_cod = codigo[::2]
inverter = codigo[::-1] #inverter
pedaco = codigo[2:10:2]
pedaco_inv = codigo[10:2:-2]

print(pedaco_cod)
print(inverter)
print(pedaco)
print(pedaco_inv)
# Out:
# 25
# 29
# 27
# 12345123479
# 9.7,4.3.2,1,5,4.3.2.1
# 2345
# 1543

# %% [markdown]
# #### **1.** Tamanho de strings. Faça um programa que leia 2 strings e informe o conteúdo delas seguido do seu comprimento. Informe também se as duas strings possuem o mesmo comprimento e são iguais ou diferentes no conteúdo.
# <pre>
# Compara duas strings
# String 1: Brasil Hexa 2006
# String 2: Brasil! Hexa 2006!
# Tamanho de "Brasil Hexa 2006": 16 caracteres
# Tamanho de "Brasil! Hexa 2006!": 18 caracteres
# As duas strings são de tamanhos diferentes.
# As duas strings possuem conteúdo diferente.
# </pre>

# %%
print('Comparar duas strings')

texto1 = input("Digite o 1º texto: ")
texto2 = input("Digite o 2º texto: ")

print("Tamanho de '{}': {} caracteres".format(texto1, len(texto1)))
print("Tamanho de '{}': {} caracteres".format(texto2, len(texto2)))

if len(texto1) == len(texto2):
  print("As duas strings são de tamanhos iguais.")
else:
  print("As duas strings são de tamanhos diferentes.")

if texto1 == texto2:
  print("As duas strings possuem conteúdo igual.")
else:
  print("As duas strings possuem conteúdo diferente.")
# Out:
# Comparar duas strings
# Digite o 1º texto: banana
# Digite o 2º texto: bana
# Tamanho de 'banana': 6 caracteres
# Tamanho de 'bana': 4 caracteres
# As duas strings são de tamanhos diferentes.
# As duas strings possuem conteúdo diferente.

# %% [markdown]
# #### 2. Valida e corrige número de telefone. Faça um programa que leia um número de telefone, e corrija o número no caso deste conter somente 7 dígitos, acrescentando o '3' na frente. O usuário pode informar o número com ou sem o traço separador.
# <pre>
# Valida e corrige número de telefone
# Telefone: 461-0133
# Telefone possui 7 dígitos. Vou acrescentar o digito três na frente.
# Telefone corrigido sem formatação: 34610133
# Telefone corrigido com formatação: 3461-0133
# </pre>

# %%
print("Valida e corrige número de telefone")

numero = input("Digite o número de telefone: ")

num = numero.replace('-', '')
if len(num) == 7:
  print("Telefone possui 7 dígitos. Vou acrescentar o digito três na frente.")
  num = '3' + num
  print(f"Telefone corrigido sem formatação: {num}")
  print(f"Telefone corrigido com formatação: {num[:4]}-{num[4:]}")
else:
  print("O telefone não tem 7 dígitos.")
# Out:
# Valida e corrige número de telefone
# Digite o número de telefone1234567
# Telefone possui 7 dígitos. Vou acrescentar o digito três na frente.
# Telefone corrigido sem formatação: 31234567
# Telefone corrigido com formatação: 3123-4567

# %% [markdown]
# raio = float("%:.2f" % input())
